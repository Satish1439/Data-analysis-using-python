# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3,5,8,21,4]
y=[1,2,3,5,8,21,4]
plt.plot(x,y)#line graph #title,lales,legend,color,width,markers
plt.title("My First plot")
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
#There are 5 subjects psycology,nano technology,Medicine,Oncology,Anthropology two students applied two do masters in any of these 5 fields with lineplot show in which field they can excel the cut of marks 70
student1=[67,45,73,71,57]
student2=[43,67,68,53,85]
subjects=["pltsycology","nano technology","Medicine","Oncology","Anthropology" ]
cut=[70,70,70,70,70]
#plt.plottype(x,y,label,color,marker,linewidth,linestyle)
plt.scatter(subjects,student1,label="student1",color="k",marker='p')
plt.scatter(subjects,student2,label="student2",color="m")
plt.plot(subjects,cut,label="cutoff",color='r',linestyle=':',linewidth='3')
plt.legend()
plt.xlabel("subjects")
plt.ylabel("Marks")
# Out:
# Text(0, 0.5, 'Marks')

# %%
#AN India vs australia is on live india as given 298 as target for australia the runs for every 5over22s is given as follows
#25,51,84,131,160,189,220,250,267,297
#australia have complited 25 overs,
#15,41,94,110,151
#plot overs vs runs for both the countries with the as the blue line australia yellow line
#with required lables and legend ,the marker for india is Flag and aystralia is plus
#take overs from a range function create runs as arrays linewidth=2

import numpy as np
IND=np.array([25,51,84,131,160,189,220,250,267,297])
AUS=np.array([15,41,94,110,151])
overs_australia=np.arange(5,26,5)
c=np.arange(5,51,5)
plt.title("IND v/s AUS")
plt.xlabel("overs")
plt.ylabel("runs")
plt.plot(overs_india,IND,label="IND",color='b',marker="s",linewidth='2')
plt.plot(overs_australia,AUS,label="AUS",color="y",marker="p",linewidth="2")
plt.legend()
plt.grid()
