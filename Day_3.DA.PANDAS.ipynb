# %% [markdown]
# PANDAS

# %%
import pandas as pd

# %%
#series enter c,pd.series(column,index)
a=["a","b","c","d","e","f","g"]
index=[1,2,3,4,5,6,7]#capital S  (s)eries
r=pd.Series(index,a)
print(r)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
grad=pd.read_csv("/content/demodt.txt",sep=",")
grad
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diax=pd.read_csv("/content/diabetcsv (1).csv")
diax
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diaxls=pd.read_excel("/content/diabetes.xlsx")
diaxls
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diax.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
pc = pd.read_csv("/content/demodt.txt")
print(pc.shape) #get the number of rows and columns
print(pc.shape[0])
print(pc.shape[1])
# Out:
# (26, 5)
# 26
# 5

# %% [markdown]
# df=pd.read_csv("/content/grades_withnulls.csv")
# df

# %%
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df.dropna()#temporary drops null values and shows
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df = pd.read_csv("/content/grades_withnulls.csv")
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna()#temporary drops null values and shows
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1 = pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace=True)
df1
# to save the changes ,create new dataframe or give inplace =True
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1 = pd.read_csv("/content/grades_withnulls.csv")
df1.fillna(555)
# Nan is replaced with 555
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
mv=df1['SEM1'].mean()
print(mv)
df1.fillna(mv,inplace=True)
df1
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
mydf1=pd.read_csv("/content/grades_withnulls.csv")
mv=df1['SEM1'].mean()
print(mv)
df1.fillna(mv,inplace=True)
mydf1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3fc9a28a2bdc> in <cell line: 2>()
#       1 mydf1=pd.read_csv("/content/grades_withnulls.csv")
# ----> 2 mv=df1['SEM1'].mean()
#       3 print(mv)
#       4 df1.fillna(mv,inplace=True)
#       5 mydf1
#
# NameError: name 'df1' is not defined

# %%
#Access the data
#Iloc=access integer location,index
#loc=access both fileds names,index
#dfname.loc[index]--->rows
#dfname.loc[st:stop]---->range of rows
#dfname.loc[r_ind,col-name]--->rows&columns

mydf1.loc[0]#first record only
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
mydf1.loc[0:5]#first five records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1

# %%
mydf1.loc[8:10]#range of record
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0

# %%
mydf1.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
mydf1.iloc[10:12,0:2]#both rows and column indexes
# Out:
#     Names Initials
# 10  Kiran        V
# 11   Maya        N

# %%
mydf1[mydf1.Grade=='A']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
#print records who score 9.3 in sem3
mydf1[mydf1.SEM3==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#printing names of score more then 9.8 in SEM1
mydf1.loc[mydf1.SEM1>9.8,"Names"]
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
#print the grades of students who scored more than 9.7 in sem3
mydf1.loc[mydf1.SEM3>9.7,"Grade"]
#accessing the records with sem>9.7 but printing only grade column
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
mydf1.drop_duplicates(inplace=True)#remove duplicates record from the file
print(mydf1)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf1.head(8)#first top 8 records there is no number display  top 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1

# %%
mydf1.tail(7)#top to down last indexes count in last given record number
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(mydf1[mydf1.index==1])#access using index positions
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
# accessing using index function
print(mydf1[mydf1.index==7])
print("Accessing specific row and col")
print(mydf1.loc[mydf1.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# Accessing specific row and col
# 7    B
# Name: Grade, dtype: object

# %%
#coloumns
mydf1.columns#display the columns in a record
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
colnames=mydf1.columns#another way of columns nmaes display
print(colnames)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
collist=list(mydf1.columns)
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#rename the column
mydf1.rename(columns={'Grade':'GPA'},inplace=True)
mydf1.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
#creating a new colummn
#dfname['new col']=values
mydf1["Conduct"]="Good"
mydf1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed Conduct
# 0      Joe        K   9.8  10.0   9.9  A+       1    Good
# 1   Rajesh        M   8.9   9.1   9.3   A       1    Good
# 2   Kissan        V   9.9   9.8  10.0   A       0    Good
# 3     Mary        N   7.7   8.0   NaN   B       0    Good
# 4     Jeen        K   9.8   9.1   9.9  A+       1    Good
# 5      Raj        M   8.9   9.1   9.3   A       1    Good
# 6   Hassan        V   9.9   9.0   9.2   A       1    Good
# 7     Mari        N   7.7   8.0   7.1   B       1    Good
# 8     Jess        K   NaN   9.1   9.9  A+       1    Good
# 9   Rajini        M   NaN   9.1   9.3   A       0    Good
# 10   Kiran        V   NaN   9.3   9.2   A       0    Good
# 11    Maya        N   7.7   8.0   7.1   B       0    Good
# 12   Jolin        K   9.8   9.1   9.9  A+       1    Good
# 14    Riya        M   9.3   9.9  10.0   A       1    Good
# 15    Sana        V   9.9   9.3   9.2   A       0    Good
# ...

# %%
#create new column averge with average values of sem1,sem2,sem3
mydf1["Average"]=(mydf1["SEM1"]+mydf1["SEM2"]+mydf1["SEM3"])/3
mydf1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed Conduct   Average
# 0      Joe        K   9.8  10.0   9.9  A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3   A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0   A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN   B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9  A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3   A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2   A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1   B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9  A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3   A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2   A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1   B       0    Good  7.600000
# 12   Jolin        K   9.8   9.1   9.9  A+       1    Good  9.600000
# ...

# %%
mydf["Average"]=(mydf1["SEM1"]+mydf1["SEM2"]+mydf1["SEM3"])/3
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# ...

# %% [markdown]
# **PLOTTING  WITH PANDAS**

# %%
#PLOTTING WITH PANDAS
df['SEM1'].plot.line()
#dfname['col'].plot.line()
# Out:
# <Axes: >

# %%
mydf= pd.read_csv("/content/grades_withnulls.csv")
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf['SEM1'].plot.line()
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot(kind="scatter",x="Average",y="Names")#y axis-numeric datadype
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
mydf.plot(kind="hist",x="Names",y="Average")
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf.to_csv("mydf.csv")
